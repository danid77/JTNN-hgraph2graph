# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import DataLoader
import math, random, sys
import numpy as np
import argparse
import os
from tqdm import tqdm
import pandas as pd

sys.path.append('/home/lnptest/SB_jin/git_test/hgraph2graph_wandb/')
from hgraph import *
from hgraph import vocab2
import rdkit

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "2"  # Set the GPU 2 to use

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())

lg = rdkit.RDLogger.logger() 
lg.setLevel(rdkit.RDLogger.CRITICAL)

# argparse 대신 직접 args 설정
class Args:
    vocab = "recovered_vocab_2000.txt"
    atom_vocab = common_atom_vocab
    model = "ckpt/model_origin.ckpt"
    seed = 7
    nsample = 100
    rnn_type = 'LSTM'
    hidden_size = 250
    embed_size = 250
    batch_size = 50
    latent_size = 32
    depthT = 15
    depthG = 15
    diterT = 1
    diterG = 3
    dropout = 0.0

args = Args()


vocab = [x.strip("\r\n ").split() for x in open(args.vocab)] 
args.vocab = PairVocab(vocab)

model = HierVAE(args).to(device)
    
model.load_state_dict(torch.load(args.model)[0])
model.eval()
# Out:
# Device: cuda
# Current cuda device: 0
# Count of using GPUs: 4
# HierVAE(
#   (encoder): HierMPNEncoder(
#     (E_c): Sequential(
#       (0): Embedding(1578, 250)
#       (1): Dropout(p=0.0, inplace=False)
#     )
#     (E_i): Sequential(
#       (0): Embedding(5623, 250)
#       (1): Dropout(p=0.0, inplace=False)
#     )
#     (W_c): Sequential(
#       (0): Linear(in_features=500, out_features=250, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#     )
#     (W_i): Sequential(
#       (0): Linear(in_features=500, out_features=250, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#     )
#     (W_root): Sequential(
#       (0): Linear(in_features=500, out_features=250, bias=True)
#       (1): Tanh()
#     )
#     (tree_encoder): MPNEncoder(
#       (W_o): Sequential(
#         (0): Linear(in_features=500, out_features=250, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (rnn): LSTM(
#         (W_i): Sequential(
#           (0): Linear(in_features=520, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W_o): Sequential(
#           (0): Linear(in_features=520, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W_f): Sequential(
#           (0): Linear(in_features=520, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W): Sequential(
#           (0): Linear(in_features=520, out_features=250, bias=True)
#           (1): Tanh()
#         )
#       )
#     )
#     (inter_encoder): MPNEncoder(
#       (W_o): Sequential(
#         (0): Linear(in_features=500, out_features=250, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (rnn): LSTM(
#         (W_i): Sequential(
#           (0): Linear(in_features=520, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W_o): Sequential(
#           (0): Linear(in_features=520, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W_f): Sequential(
#           (0): Linear(in_features=520, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W): Sequential(
#           (0): Linear(in_features=520, out_features=250, bias=True)
#           (1): Tanh()
#         )
#       )
#     )
#     (graph_encoder): MPNEncoder(
#       (W_o): Sequential(
#         (0): Linear(in_features=288, out_features=250, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (rnn): LSTM(
#         (W_i): Sequential(
#           (0): Linear(in_features=312, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W_o): Sequential(
#           (0): Linear(in_features=312, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W_f): Sequential(
#           (0): Linear(in_features=312, out_features=250, bias=True)
#           (1): Sigmoid()
#         )
#         (W): Sequential(
#           (0): Linear(in_features=312, out_features=250, bias=True)
#           (1): Tanh()
#         )
#       )
#     )
#   )
#   (decoder): HierMPNDecoder(
#     (hmpn): IncHierMPNEncoder(
#       (E_c): Sequential(
#         (0): Embedding(1578, 250)
#         (1): Dropout(p=0.0, inplace=False)
#       )
#       (E_i): Sequential(
#         (0): Embedding(5623, 250)
#         (1): Dropout(p=0.0, inplace=False)
#       )
#       (W_c): Sequential(
#         (0): Linear(in_features=500, out_features=250, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (W_i): Sequential(
#         (0): Linear(in_features=500, out_features=250, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (tree_encoder): IncMPNEncoder(
#         (W_o): Sequential(
#           (0): Linear(in_features=500, out_features=250, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.0, inplace=False)
#         )
#         (rnn): LSTM(
#           (W_i): Sequential(
#             (0): Linear(in_features=520, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W_o): Sequential(
#             (0): Linear(in_features=520, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W_f): Sequential(
#             (0): Linear(in_features=520, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W): Sequential(
#             (0): Linear(in_features=520, out_features=250, bias=True)
#             (1): Tanh()
#           )
#         )
#       )
#       (inter_encoder): IncMPNEncoder(
#         (W_o): Sequential(
#           (0): Linear(in_features=500, out_features=250, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.0, inplace=False)
#         )
#         (rnn): LSTM(
#           (W_i): Sequential(
#             (0): Linear(in_features=520, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W_o): Sequential(
#             (0): Linear(in_features=520, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W_f): Sequential(
#             (0): Linear(in_features=520, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W): Sequential(
#             (0): Linear(in_features=520, out_features=250, bias=True)
#             (1): Tanh()
#           )
#         )
#       )
#       (graph_encoder): IncMPNEncoder(
#         (W_o): Sequential(
#           (0): Linear(in_features=288, out_features=250, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.0, inplace=False)
#         )
#         (rnn): LSTM(
#           (W_i): Sequential(
#             (0): Linear(in_features=312, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W_o): Sequential(
#             (0): Linear(in_features=312, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W_f): Sequential(
#             (0): Linear(in_features=312, out_features=250, bias=True)
#             (1): Sigmoid()
#           )
#           (W): Sequential(
#             (0): Linear(in_features=312, out_features=250, bias=True)
#             (1): Tanh()
#           )
#         )
#       )
#     )
#     (rnn_cell): LSTM(
#       (W_i): Sequential(
#         (0): Linear(in_features=520, out_features=250, bias=True)
#         (1): Sigmoid()
#       )
#       (W_o): Sequential(
#         (0): Linear(in_features=520, out_features=250, bias=True)
#         (1): Sigmoid()
#       )
#       (W_f): Sequential(
#         (0): Linear(in_features=520, out_features=250, bias=True)
#         (1): Sigmoid()
#       )
#       (W): Sequential(
#         (0): Linear(in_features=520, out_features=250, bias=True)
#         (1): Tanh()
#       )
#     )
#     (E_assm): Sequential(
#       (0): Embedding(5623, 250)
#       (1): Dropout(p=0.0, inplace=False)
#     )
#     (topoNN): Sequential(
#       (0): Linear(in_features=282, out_features=250, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=250, out_features=1, bias=True)
#     )
#     (clsNN): Sequential(
#       (0): Linear(in_features=282, out_features=250, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=250, out_features=1578, bias=True)
#     )
#     (iclsNN): Sequential(
#       (0): Linear(in_features=282, out_features=250, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=250, out_features=5623, bias=True)
#     )
#     (matchNN): Sequential(
#       (0): Linear(in_features=520, out_features=250, bias=True)
#       (1): ReLU()
#     )
#     (W_assm): Linear(in_features=250, out_features=32, bias=True)
#     (W_root): Linear(in_features=32, out_features=250, bias=True)
#     (topo_loss): BCEWithLogitsLoss()
#     (cls_loss): CrossEntropyLoss()
#     (icls_loss): CrossEntropyLoss()
#     (assm_loss): CrossEntropyLoss()
#   )
#   (R_mean): Linear(in_features=250, out_features=32, bias=True)
#   (R_var): Linear(in_features=250, out_features=32, bias=True)
# )

# %%
torch.manual_seed(args.seed)
random.seed(args.seed)


sm_list = []
smiles_list = []
with torch.no_grad():
    for _ in tqdm(range(args.nsample // args.batch_size)):
        smiles_list = model.sample(args.batch_size, greedy=True)
        for _,smiles in enumerate(smiles_list):
            sm_list.append(smiles)
            
# with torch.no_grad():
#     for _ in tqdm(range((args.nsample + args.batch_size - 1) // args.batch_size)):
#         batch_smiles_list = model.sample(args.batch_size, greedy=True)
#         valid_smiles_list = [smiles for smiles in batch_smiles_list if smiles is not None]  # None 값 필터링
#         smiles_list.extend(valid_smiles_list)
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]

# %%
print(len(sm_list))
sm_list
# Out:
# 100
# ['C=Cc1c(C2OC(=O)C(C)=C(C)C23OC(c2ccccc2)=NC(c2ccccc2)C3c2ccccc2)c(CCc2ccccc2)c(C2OC(=O)C(C)=C(C)C23OC(c2ccccc2)=NC(c2ccccc2)C3c2ccccc2)c(C(C)=O)c1C1OC(=O)C(C)=C(C)C12OC(c1ccccc1)=NC(c1ccccc1)C2c1ccccc1',
#  'Cc1cn(S(=O)(=O)CS)nc1Br',
#  'COCCC(C)=O',
#  'C=O',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCN(O)C1CC(CCCCCCCCCCC)C1=O',
#  'COCC(C)=O',
#  'C=O',
#  'CC(=O)c1c(C)c(C(C)=O)c(C(C)(C)C)c(C(C)=O)c1C(C)=O',
#  'COC(C)=O',
#  'CC(C)=O',
#  'CC(C)=O',
#  'COC1C=CC=CC12CCN(C1(N)CC(C)C1(C)C)C1CN(c3cn[nH]c3)CC12',
#  'C=CCCCCCCCC',
#  'COC(C)=O',
#  'CCc1cccc(OC)c1',
#  'CC(=O)CCC1C(=O)OC(C)=C1C1=C(C(C)=O)C(CCC(C)=O)C(=O)O1',
#  'O=C1NNC(=O)C1=O',
#  'CC(C)=O',
#  'C=O',
#  'CS(N)(=O)=O',
#  'COC1(C(C)=O)OC2(C(=O)C(=O)N(C)C2=O)N1C',
#  'Cc1nc2n(c1-c1cccc(F)c1)C(=O)C(=O)N(C1C=C(Cc3cccc(F)c3)C=CN1C)C(=O)C2=O',
#  'COC(C)(C)C',
#  'CC1CC(N2C(=O)C3(C4C2OC(=S)N4C2NC(=O)c4ccccc42)N(C2C(=O)N(C4CCNC4)C4(C2=O)C2(ON5C4(C)C(=O)C46C(=O)N(C78CC(=O)C7C(=O)N(CN=O)C8=O)C(=O)C54OC(=O)N6C45CNCC4C(=O)C(=O)N5)C(=O)C(=O)N(C45CC(=O)C4C(=O)N(CN=O)C5=O)C2=O)OC(=O)C32C(=Cc3cc4ccccc4n3CN=O)CC2(N=O)N2CC(N3CCC=N3)C(=O)C2=O)C1=O',
#  'CS(N)(=O)=O',
#  'CC(C)=O',
#  'CC(C)(C)C',
#  'COC=C=O',
#  'CC(C)=O',
#  'CF',
#  'CCCC',
#  'COCC(C)=O',
#  'C=O',
#  'C=O',
#  'CC(C)=O',
#  'CSCSC[SH]1C(C)=CCC1c1nc(C2(C3N=C(c4c(Cl)c(Cl)c(Cl)c(Cl)c4Cl)N3C3CCC3)N=C(c3c(Cl)c(Cl)c(Cl)c(Cl)c3Cl)N2C2CCC2)no1',
#  'CN(CCCCCCCCc1ccccc1)C1CC(CCc2ccccc2)C1',
#  'CCC(C)=O',
#  'CC(C)=O',
#  'CS(C)(=O)=O',
#  'CC1C(CCCCCCc2ccccc2)CC1[N+](C)(C)[O-]',
#  'CC(C)=O',
#  'CCc1ccc(C)cc1',
#  'CN(O)C1CC(=O)C1=O',
#  'CC(C)(C)C',
#  'C[N+]([O-])(O)C1CC(=O)C1C(=O)F',
#  'C=O',
#  'CCCCCCCCCC',
#  'CC1(C)C([N+](C)([O-])O)C2CN(CCCc3ccccc3)CC21CCc1ccccc1',
#  'CC(C)(C)C',
#  'CC1C(F)=C(F)C(NCC2=CC3N=CN=CC3(C)S2)=NN1C',
#  'CC(C)(C)C',
#  'CC(C)=O',
#  'C=O',
#  'C=O',
#  'CC(C)=O',
#  'O=C(F)CCl',
#  'CN1c2ccccc2[NH2+]C(=S)C1[N+](C)=O',
#  'CC(C)=O',
#  'CN(C)C1CCC1',
#  'CN(C)C',
#  'C=O',
#  'CCCCC',
#  'COCC#CC#Cc1ccccc1',
#  'C=[SH]CSC[SH2+]',
#  'CN(C)C1CCC1=O',
#  'Cc1nonc1-c1nonc1C(C)(C)C',
#  'C=CCC',
#  'CSCSCS',
#  'CCC(C)=O',
#  'C=O',
#  'CCCCCc1ccc(C)cc1',
#  'Cc1nc(-c2ccc(Cl)c(Cl)c2C2C(c3ccc(Cl)c(Cl)c3C3C(c4ccc(Cl)c(Cl)c4C4C(c5ccc(Cl)c(Cl)c5C5C(c6ccc(Cl)c(Cl)c6C6C(c7ccc(Cl)c(Cl)c7C7C(c8ccc(Cl)c(Cl)c8C8C(c9ccc(Cl)c(Cl)c9C9C(c%10ccc(Cl)c(Cl)c%10C%10C(c%11ccc(Cl)c(Cl)c%11C%11C(c%12ccc(Cl)c(Cl)c%12C%12C(c%13ccc(Cl)c(Cl)c%13C%13CC=NN%13C)C=NN%12c%12ncc[nH]%12)C=NN%11c%11ncc[nH]%11)C=NN%10c%10ncc[nH]%10)C=NN9c9ncc[nH]9)C=NN8c8ncc[nH]8)C=NN7c7ncc[nH]7)C=NN6c6ncc[nH]6)C=NN5c5ncc[nH]5)C=NN4c4ncc[nH]4)C=NN3c3ncc[nH]3)C=NN2c2ncc[nH]2)n(CN)c1-c1cccnc1',
#  'CC(=O)CCCCCCCl',
#  'CC(C)=O',
#  'Cc1nn(C2(N(O)O)CC3(c4ccccc4)N=CN=C4C=NC=CC432)c(C)c1C',
#  'CC(C)(C)C',
#  'CNCN1C(OC)=NC(=O)C(=O)C1C(C)=O',
#  'CC=CC=C(C)C',
#  'COCCCCCc1ccccc1',
#  'CCCCC=NC',
#  'CC(=O)c1c(C)c(C(C)=O)c(C(C)(C)C)c(C(C)=O)c1C(C)=O',
#  'COCCCC1N=CC(C2N=CC(C3N=CC(C4N=CC(C5N=CC(C6N=CC(C7N=CC(C8N=CC(C9N=CC(C%10N=CC(C%11N=CC(C%12N=CC(C)=CC%12C(C)=O)=CC%11C(C)=O)=CC%10C(C)=O)=CC9C(C)=O)=CC8C(C)=O)=CC7C(C)=O)=CC6C(C)=O)=CC5C(C)=O)=CC4C(C)=O)=CC3C(C)=O)=CC2C(C)=O)=CC12C(c1cccc(-c3ccccc3)c1)C(C=O)=NN2CNC1CCC1',
#  'CC(=O)CCCc1ccccc1',
#  'CCCc1ccc(-c2ccccc2)c2c1C(=O)N(C)C2=O',
#  'O=C(Cl)Cl',
#  'NN(O)C1C(=S)c2ccccc21',
#  'CCCCCCCCC',
#  'CC(C)=O',
#  'CCCCCC',
#  'COCCC(=O)CC=CC=CC(C)=O',
#  'O=C=Cc1ccc(Cl)c(Cl)c1',
#  'CCCCCCCCCCCCNC',
#  'C[N+](C)([O-])O',
#  'C=CCCCCCCC',
#  'CCCCC',
#  'CCCCCCc1c(C)cc(C(C)(C)C)nc1C',
#  'CCCC',
#  'O=c1c(=O)n1CNC1CCC1',
#  'CCC(C)=O']

# %%
# DataFrame으로 변환
df = pd.DataFrame(sm_list, columns=['SMILES']) 
df.to_csv('result.csv')
df

# %%
smiles_list

# %%
df

# %%
print(dir(args.vocab))

# %%
print(args.vocab)

# %% [markdown]
# # we train

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import DataLoader
import math, random, sys
import numpy as np
import argparse
import os
from tqdm import tqdm
import pandas as pd

sys.path.append('/home/lnptest/SB_jin/git_test/hgraph2graph_wandb/')
from hgraph import *
# from hgraph import vocab2
import rdkit

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "2"  # Set the GPU 2 to use

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())

lg = rdkit.RDLogger.logger() 
lg.setLevel(rdkit.RDLogger.CRITICAL)

# argparse 대신 직접 args 설정
class Args:
    vocab = "vocab.txt"
    atom_vocab = common_atom_vocab
    model = "/home/lnptest/SB_jin/git_test/hgraph2graph_wandb/ckpt/chembl-240709-150/model_1604.ckpt"
    seed = 7
    nsample = 100000
    rnn_type = 'LSTM'
    hidden_size = 512
    embed_size = 512
    batch_size = 50
    latent_size = 32
    depthT = 15
    depthG = 15
    diterT = 1
    diterG = 3
    dropout = 0.0

args = Args()


vocab = [x.strip("\r\n ").split() for x in open(args.vocab)] 
args.vocab = PairVocab(vocab)

model = HierVAE(args).to(device)
    
model.load_state_dict(torch.load(args.model)[0])
model.eval()
# Out:
# Device: cuda
# Current cuda device: 0
# Count of using GPUs: 4
# /home/lnptest/anaconda3/envs/jtnn_test/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# HierVAE(
#   (encoder): HierMPNEncoder(
#     (E_c): Sequential(
#       (0): Embedding(1576, 512)
#       (1): Dropout(p=0.0, inplace=False)
#     )
#     (E_i): Sequential(
#       (0): Embedding(5625, 512)
#       (1): Dropout(p=0.0, inplace=False)
#     )
#     (W_c): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#     )
#     (W_i): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#     )
#     (W_root): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): Tanh()
#     )
#     (tree_encoder): MPNEncoder(
#       (W_o): Sequential(
#         (0): Linear(in_features=1024, out_features=512, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (rnn): LSTM(
#         (W_i): Sequential(
#           (0): Linear(in_features=1044, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W_o): Sequential(
#           (0): Linear(in_features=1044, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W_f): Sequential(
#           (0): Linear(in_features=1044, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W): Sequential(
#           (0): Linear(in_features=1044, out_features=512, bias=True)
#           (1): Tanh()
#         )
#       )
#     )
#     (inter_encoder): MPNEncoder(
#       (W_o): Sequential(
#         (0): Linear(in_features=1024, out_features=512, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (rnn): LSTM(
#         (W_i): Sequential(
#           (0): Linear(in_features=1044, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W_o): Sequential(
#           (0): Linear(in_features=1044, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W_f): Sequential(
#           (0): Linear(in_features=1044, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W): Sequential(
#           (0): Linear(in_features=1044, out_features=512, bias=True)
#           (1): Tanh()
#         )
#       )
#     )
#     (graph_encoder): MPNEncoder(
#       (W_o): Sequential(
#         (0): Linear(in_features=550, out_features=512, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (rnn): LSTM(
#         (W_i): Sequential(
#           (0): Linear(in_features=574, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W_o): Sequential(
#           (0): Linear(in_features=574, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W_f): Sequential(
#           (0): Linear(in_features=574, out_features=512, bias=True)
#           (1): Sigmoid()
#         )
#         (W): Sequential(
#           (0): Linear(in_features=574, out_features=512, bias=True)
#           (1): Tanh()
#         )
#       )
#     )
#   )
#   (decoder): HierMPNDecoder(
#     (hmpn): IncHierMPNEncoder(
#       (E_c): Sequential(
#         (0): Embedding(1576, 512)
#         (1): Dropout(p=0.0, inplace=False)
#       )
#       (E_i): Sequential(
#         (0): Embedding(5625, 512)
#         (1): Dropout(p=0.0, inplace=False)
#       )
#       (W_c): Sequential(
#         (0): Linear(in_features=1024, out_features=512, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (W_i): Sequential(
#         (0): Linear(in_features=1024, out_features=512, bias=True)
#         (1): ReLU()
#         (2): Dropout(p=0.0, inplace=False)
#       )
#       (tree_encoder): IncMPNEncoder(
#         (W_o): Sequential(
#           (0): Linear(in_features=1024, out_features=512, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.0, inplace=False)
#         )
#         (rnn): LSTM(
#           (W_i): Sequential(
#             (0): Linear(in_features=1044, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W_o): Sequential(
#             (0): Linear(in_features=1044, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W_f): Sequential(
#             (0): Linear(in_features=1044, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W): Sequential(
#             (0): Linear(in_features=1044, out_features=512, bias=True)
#             (1): Tanh()
#           )
#         )
#       )
#       (inter_encoder): IncMPNEncoder(
#         (W_o): Sequential(
#           (0): Linear(in_features=1024, out_features=512, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.0, inplace=False)
#         )
#         (rnn): LSTM(
#           (W_i): Sequential(
#             (0): Linear(in_features=1044, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W_o): Sequential(
#             (0): Linear(in_features=1044, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W_f): Sequential(
#             (0): Linear(in_features=1044, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W): Sequential(
#             (0): Linear(in_features=1044, out_features=512, bias=True)
#             (1): Tanh()
#           )
#         )
#       )
#       (graph_encoder): IncMPNEncoder(
#         (W_o): Sequential(
#           (0): Linear(in_features=550, out_features=512, bias=True)
#           (1): ReLU()
#           (2): Dropout(p=0.0, inplace=False)
#         )
#         (rnn): LSTM(
#           (W_i): Sequential(
#             (0): Linear(in_features=574, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W_o): Sequential(
#             (0): Linear(in_features=574, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W_f): Sequential(
#             (0): Linear(in_features=574, out_features=512, bias=True)
#             (1): Sigmoid()
#           )
#           (W): Sequential(
#             (0): Linear(in_features=574, out_features=512, bias=True)
#             (1): Tanh()
#           )
#         )
#       )
#     )
#     (rnn_cell): LSTM(
#       (W_i): Sequential(
#         (0): Linear(in_features=1044, out_features=512, bias=True)
#         (1): Sigmoid()
#       )
#       (W_o): Sequential(
#         (0): Linear(in_features=1044, out_features=512, bias=True)
#         (1): Sigmoid()
#       )
#       (W_f): Sequential(
#         (0): Linear(in_features=1044, out_features=512, bias=True)
#         (1): Sigmoid()
#       )
#       (W): Sequential(
#         (0): Linear(in_features=1044, out_features=512, bias=True)
#         (1): Tanh()
#       )
#     )
#     (E_assm): Sequential(
#       (0): Embedding(5625, 512)
#       (1): Dropout(p=0.0, inplace=False)
#     )
#     (topoNN): Sequential(
#       (0): Linear(in_features=544, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=512, out_features=1, bias=True)
#     )
#     (clsNN): Sequential(
#       (0): Linear(in_features=544, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=512, out_features=1576, bias=True)
#     )
#     (iclsNN): Sequential(
#       (0): Linear(in_features=544, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=512, out_features=5625, bias=True)
#     )
#     (matchNN): Sequential(
#       (0): Linear(in_features=1044, out_features=512, bias=True)
#       (1): ReLU()
#     )
#     (W_assm): Linear(in_features=512, out_features=32, bias=True)
#     (W_root): Linear(in_features=32, out_features=512, bias=True)
#     (topo_loss): BCEWithLogitsLoss()
#     (cls_loss): CrossEntropyLoss()
#     (icls_loss): CrossEntropyLoss()
#     (assm_loss): CrossEntropyLoss()
#   )
#   (R_mean): Linear(in_features=512, out_features=32, bias=True)
#   (R_var): Linear(in_features=512, out_features=32, bias=True)
# )

# %%
torch.manual_seed(args.seed)
random.seed(args.seed)


sm_list = []
smiles_list = []
with torch.no_grad():
    for _ in tqdm(range(args.nsample // args.batch_size)):
        smiles_list = model.sample(args.batch_size, greedy=True)
        # print(type(smiles_list))
        # print(smiles_list[:5])
        for _,smiles in enumerate(smiles_list):
            sm_list.append(smiles)
# Out:
#  25%|██▌       | 5/20 [00:00<00:00, 21.19it/s]
# <class 'list'>
# ['CC', 'CC', 'CCC', 'CC', 'CCC']
# <class 'list'>
# ['CC', 'CC', 'CC', 'CC', 'CO']
# <class 'list'>
# ['CCNC', 'CC', 'CC', 'CC', 'CCC']
# <class 'list'>
# ['CC', 'CC', 'CC', 'CCC', 'CC']
# <class 'list'>
# ['CC', 'CC', 'CCC', 'CC', 'CCC']
#  40%|████      | 8/20 [00:00<00:00, 21.84it/s]
# <class 'list'>
# ['CCC', 'CC', 'CC', 'CNC', 'CC']
# <class 'list'>
# ['CCCC', 'CCC', 'CC', 'CC', 'CNC']
# <class 'list'>
# ['CC', 'CCC', 'CC', 'CC', 'CO']
# <class 'list'>
# ['CNC', 'CC', 'CC', 'CCC', 'CCC']
# <class 'list'>
# ['CC', 'CC', 'CCC', 'CC', 'CC']
# <class 'list'>
# ['CCC', 'CC', 'CC', 'CCC', 'CCC']
#  70%|███████   | 14/20 [00:00<00:00, 23.56it/s]
# <class 'list'>
# ['CCC', 'CC', 'CCC', 'CC', 'CNC']
# <class 'list'>
# ['CC', 'CC', 'CC', 'CCC', 'CO']
# <class 'list'>
# ['CC', 'CC', 'CC', 'CC', 'CNC']
# <class 'list'>
# ['CNC', 'CC', 'CN', 'CC', 'CCC']
# <class 'list'>
# ['CNC', 'CO', 'CO', 'CC', 'CCC']
# 100%|██████████| 20/20 [00:00<00:00, 22.93it/s]
# <class 'list'>
# ['CNC', 'CC', 'CO', 'CC', 'CC=O']
# <class 'list'>
# ['CC', 'CCC', 'CC', 'CCC', 'CNC']
# <class 'list'>
# ['CCC', 'CCC', 'CCC', 'CNC', 'CC']
# <class 'list'>
# ['CC', 'CNC', 'CC', 'CC', 'CNC']

# %%
torch.manual_seed(args.seed)
random.seed(args.seed)


sm_list = []
smiles_list = []
with torch.no_grad():
    for _ in tqdm(range(args.nsample // args.batch_size)):
        smiles_list = model.sample(args.batch_size, greedy=True)
        for _,smiles in enumerate(smiles_list):
            if len(smiles) > 20:
                sm_list.append(smiles)
            
# with torch.no_grad():
#     for _ in tqdm(range((args.nsample + args.batch_size - 1) // args.batch_size)):
#         batch_smiles_list = model.sample(args.batch_size, greedy=True)
#         valid_smiles_list = [smiles for smiles in batch_smiles_list if smiles is not None]  # None 값 필터링
#         smiles_list.extend(valid_smiles_list)

print(len(sm_list))
sm_list
# Out:
# 100%|██████████| 2000/2000 [01:27<00:00, 22.87it/s]
# 0
# []

# %%
print(len(sm_list))
sm_list
# Out:
# 0
# []

# %%
torch.manual_seed(args.seed)
random.seed(args.seed)


sm_list = []
smiles_list = []
with torch.no_grad():
    for _ in tqdm(range(args.nsample // args.batch_size)):
        smiles_list = model.sample(args.batch_size, greedy=True)
        for _,smiles in enumerate(smiles_list):
            if len(smiles) > 20:
                sm_list.append(smiles)
            
# with torch.no_grad():
#     for _ in tqdm(range((args.nsample + args.batch_size - 1) // args.batch_size)):
#         batch_smiles_list = model.sample(args.batch_size, greedy=True)
#         valid_smiles_list = [smiles for smiles in batch_smiles_list if smiles is not None]  # None 값 필터링
#         smiles_list.extend(valid_smiles_list)

print(len(sm_list))
sm_list
# Out:
# 100%|██████████| 200000/200000 [2:08:48<00:00, 25.88it/s]
# 30473
# ['CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1=CCCCCOCC(=O)C(C)C1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC=CC(C)NSc2ccccc2OC1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1=CCCCCOCC(=O)C(C)C1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1=CCCCCOCC(=O)C(C)C1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1=CCC(C)CCOCC(=O)CC1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1COCOC2CCCC2C(C)OC1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'C1#CCOCC2(C#CC=C1)CCN[SH+]CC2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1=CCCCCOCC(=O)C(C)C1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSN(C)CC=CCC(=O)CO1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+][NH2+]C(=O)C1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  '[O-][NH+]1CCCC[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1NC(S)[SiH2]O[SiH2]1',
#  'C1#CCOC2COCOCC2C#CC=C1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1=CCCCCOCC(=O)C(C)C1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC=CC(C)NSc2ccccc2OC1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)[NH+]([O-])[NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'O=C1CSc2ccccc2CSCCSS1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CCC(=O)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1C=CCC(=O)COc2ccccc2SN1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'CC1NC(C)[SiH2]O[SiH2]1',
#  'CC1C[NH2+]C(C)C(C)C[NH2+]1',
#  'CC1CSc2ccccc2CSCC(=O)SS1',
#  'c1ccc2c(c1)CSCCSSCCS2',
#  'CC1CC(C)C(C)[NH2+][NH2+]1',
#  'CC1COCCSNC(=O)Cc2ccccc21',
#  ...]

# %%
print(len(sm_list))
sm_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(len(sm_list))
#       2 sm_list
#
# NameError: name 'sm_list' is not defined

# %%
len(sm_list[5])
# Out:
# 25
